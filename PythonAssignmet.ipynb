# %% [markdown]
# Comments

# %%
# This is a comment

# %% [markdown]
# Multi-line Comments

# %%
""" Triple Quotes 
used for 
multi-line
comments"""
# Out:
# ' Triple Quotes \nused for \nmulti-line\ncomments'

# %% [markdown]
# Declare Variables for integer Datatype

# %%
a=54
print(a)
b=85
print(b)
c=37
print(c)
# Out:
# 54
# 85
# 37

# %% [markdown]
# Python Boleans

# %%
print(54==40)
# Out:
# False

# %%
print(25!=34)
# Out:
# True

# %%
print(57>20)
# Out:
# True

# %%
print(68<35)
# Out:
# False

# %%
print(36<= 68)
# Out:
# True

# %%
print(15>= 34)
# Out:
# False

# %% [markdown]
# Input operator

# %%
name =input("Enter your name")
print("My name is",name)
# Out:
# My name is Furqan Khan

# %% [markdown]
# Integer type input from USER

# %%
age=int(input("What is your age"))
print("My age is",age)
# Out:
# My age is 21

# %% [markdown]
# Take any Input Value from user

# %%
x=int(input("Enter a number:"))
print("Your Answer is",x)
# Out:
# Your Answer is 1970

# %% [markdown]
# Assigning Both types of quotes

# %%
print("I think,'Python is Awesome'")
# Out:
# I think,'Python is Awesome'

# %%
print('He said,"Python is Powerfull"')
# Out:
# He said,"Python is Powerfull"
