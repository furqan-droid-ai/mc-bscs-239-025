# %% [markdown]
# Print String

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Print String value and integer in one line

# %%
print("Furqan khan",90)
# Out:
# Furqan khan 90

# %% [markdown]
# Arthematic function

# %%
print(59-15,14+25,52/5,36*24)
# Out:
# 44 39 10.4 864

# %% [markdown]
# Comments

# %%
#using hashtag for comment

# %% [markdown]
# Multi-line comment

# %%
'''using tripple quotes for 
multiple lines 
comment'''
# Out:
# 'using tripple quotes for \nmultiple lines \ncomment'

# %% [markdown]
# Addition in python

# %%
print(43+69)
# Out:
# 112

# %% [markdown]
# Subtraction in python

# %%
print(58-32)
# Out:
# 26

# %% [markdown]
# Multiplication

# %%
print(78*40)
# Out:
# 3120

# %% [markdown]
# Division

# %%
print(48/6)
# Out:
# 8.0

# %% [markdown]
# declare variable

# %%
X = "Hello world"
print(X)
# Out:
# Hello world

# %% [markdown]
# declare integer

# %%
Z=69
print(Z)
# Out:
# 69

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# multiple values to multi varible in one line

# %%
x,y,z= "hassan","sanaullah","haseeb"
print(x)
print(y)
print(z)
# Out:
# hassan
# sanaullah
# haseeb

# %% [markdown]
# smae value to multiple varible in one line

# %%
x=y=z="hello"
print(x)
print(y)
print(z)
# Out:
# hello
# hello
# hello

# %% [markdown]
# declare varble and arthematic function

# %%
a = 87
b = 45
print(a + b)
# Out:
# 132
